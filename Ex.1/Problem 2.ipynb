# %%
import numpy as np
import matplotlib.pyplot as plt
import math 
import data_manipulations as dm
import plotting_functions as pf


sphere=dm.sample_sphere(10000)
cartesian_sphere =dm.get_cartesian_coords(sphere[1],sphere[0])

pf.plot_scatter(cartesian_sphere)

# %%
pf.plot_histogram(cartesian_sphere)
